# %%
from pyspark import SparkContext
sc = SparkContext.getOrCreate()
file_name = "../Data/README.md"

# %%
word = sc.textFile(file_name).flatMap(lambda x : x.split(" "))
word_rdd = word.map(lambda x : (x,1))

# %%
word_rdd.take(5)
# Out:
# [('#', 1), ('Apache', 1), ('Spark', 1), ('', 1), ('Spark', 1)]

# %% [markdown]
# ## Generate key-value pairs of (Word, Total Occurrence).

# %%
grouped_word_rdd = word_rdd.groupByKey()

# %%
grouped_word_rdd.glom().collect()
# Out:
# [[('#', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ca0d0>),
#   ('Apache', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ca4c0>),
#   ('Spark', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ca5b0>),
#   ('', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ca4f0>),
#   ('is', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ca520>),
#   ('It', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ca640>),
#   ('provides', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ca670>),
#   ('high-level', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ca760>),
#   ('APIs', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ca7c0>),
#   ('in', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ca7f0>),
#   ('Scala,', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ca850>),
#   ('Java,', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ca8b0>),
#   ('an', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ca910>),
#   ('optimized', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ca970>),
#   ('engine', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ca9d0>),
#   ('supports', <pyspark.resultiterable.ResultIterable at 0x7fe0f84caa30>),
#   ('computation', <pyspark.resultiterable.ResultIterable at 0x7fe0f84caac0>),
#   ('analysis.', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cab20>),
#   ('set', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cab80>),
#   ('of', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cac10>),
#   ('tools', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cac70>),
#   ('SQL', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cacd0>),
#   ('MLlib', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cad60>),
#   ('machine', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cadc0>),
#   ('learning,', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cae20>),
#   ('GraphX', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cae80>),
#   ('graph', <pyspark.resultiterable.ResultIterable at 0x7fe0f84caee0>),
#   ('processing,', <pyspark.resultiterable.ResultIterable at 0x7fe0f84caf40>),
#   ('Documentation', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cafa0>),
#   ('latest', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd040>),
#   ('programming', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd0a0>),
#   ('guide,', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd100>),
#   ('[project', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd160>),
#   ('README', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd1f0>),
#   ('only', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd250>),
#   ('basic', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd2b0>),
#   ('instructions.', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd310>),
#   ('Building', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd370>),
#   ('using', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd3d0>),
#   ('[Apache', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd430>),
#   ('run:', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd490>),
#   ('do', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd4f0>),
#   ('this', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd580>),
#   ('downloaded', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd5e0>),
#   ('more', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd640>),
#   ('than', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd6a0>),
#   ('-T', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd700>),
#   ('Maven', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd760>),
#   ('3"](https://cwiki.apache.org/confluence/display/MAVEN/Parallel+builds+in+Maven+3).',
#    <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd7c0>),
#   ('documentation', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd820>),
#   ('project', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd8b0>),
#   ('site,', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd910>),
#   ('at', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cd970>),
#   ('Spark"](http://spark.apache.org/docs/latest/building-spark.html).',
#    <pyspark.resultiterable.ResultIterable at 0x7fe0f84cda00>),
#   ('developing', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cda60>),
#   ('IDE,', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cdac0>),
#   ('Interactive', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cdb20>),
#   ('Shell', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cdbb0>),
#   ('The', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cdc40>),
#   ('way', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cdca0>),
#   ('start', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cdd00>),
#   ('Try', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cdd60>),
#   ('following', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cddc0>),
#   ('1000:', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cde50>),
#   ('scala>', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cdee0>),
#   ('1000).count()', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cdf40>),
#   ('Python', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cdfa0>),
#   ('Alternatively,',
#    <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1070>),
#   ('use', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d10d0>),
#   ('And', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1160>),
#   ('run', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d11c0>),
#   ('Example', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1220>),
#   ('several', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1280>),
#   ('programs', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d12e0>),
#   ('them,', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1370>),
#   ('`./bin/run-example',
#    <pyspark.resultiterable.ResultIterable at 0x7fe0f84d13d0>),
#   ('[params]`.', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1430>),
#   ('example:', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1490>),
#   ('./bin/run-example',
#    <pyspark.resultiterable.ResultIterable at 0x7fe0f84d14f0>),
#   ('SparkPi', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1580>),
#   ('variable', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1610>),
#   ('when', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1670>),
#   ('examples', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d16d0>),
#   ('spark://', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1760>),
#   ('URL,', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d17c0>),
#   ('YARN,', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1820>),
#   ('"local"', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1880>),
#   ('locally', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d18e0>),
#   ('N', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1970>),
#   ('abbreviated', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d19d0>),
#   ('class', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1a30>),
#   ('name', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1ac0>),
#   ('package.', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1b20>),
#   ('instance:', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1b80>),
#   ('print', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1be0>),
#   ('usage', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1c40>),
#   ('help', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1ca0>),
#   ('no', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1d00>),
#   ('params', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1d60>),
#   ('are', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1dc0>),
#   ('Testing', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1e20>),
#   ('Spark](#building-spark).',
#    <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1e80>),
#   ('Once', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1ee0>),
#   ('built,', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1f40>),
#   ('tests', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d1fa0>),
#   ('using:', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6070>),
#   ('./dev/run-tests',
#    <pyspark.resultiterable.ResultIterable at 0x7fe0f84d60d0>),
#   ('Please', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6130>),
#   ('guidance', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d61c0>),
#   ('module,', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6250>),
#   ('individual', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d62b0>),
#   ('Note', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ca550>),
#   ('About', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ca100>),
#   ('uses', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ca310>),
#   ('library', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ca0a0>),
#   ('HDFS', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ca280>),
#   ('other', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ca490>),
#   ('Hadoop-supported',
#    <pyspark.resultiterable.ResultIterable at 0x7fe1186069a0>),
#   ('storage', <pyspark.resultiterable.ResultIterable at 0x7fe118606520>),
#   ('systems.', <pyspark.resultiterable.ResultIterable at 0x7fe118606fa0>),
#   ('Because', <pyspark.resultiterable.ResultIterable at 0x7fe118606ee0>),
#   ('have', <pyspark.resultiterable.ResultIterable at 0x7fe118606af0>),
#   ('changed', <pyspark.resultiterable.ResultIterable at 0x7fe1186065e0>),
#   ('different', <pyspark.resultiterable.ResultIterable at 0x7fe118606d00>),
#   ('versions', <pyspark.resultiterable.ResultIterable at 0x7fe1186062e0>),
#   ('Hadoop,', <pyspark.resultiterable.ResultIterable at 0x7fe118606580>),
#   ('must', <pyspark.resultiterable.ResultIterable at 0x7fe1186063d0>),
#   ('against', <pyspark.resultiterable.ResultIterable at 0x7fe1186062b0>),
#   ('version', <pyspark.resultiterable.ResultIterable at 0x7fe118606490>),
#   ('refer', <pyspark.resultiterable.ResultIterable at 0x7fe118606340>),
#   ('particular', <pyspark.resultiterable.ResultIterable at 0x7fe118606df0>),
#   ('distribution', <pyspark.resultiterable.ResultIterable at 0x7fe1185f3a00>),
#   ('Hive', <pyspark.resultiterable.ResultIterable at 0x7fe1185f3700>),
#   ('Thriftserver', <pyspark.resultiterable.ResultIterable at 0x7fe1185f3520>),
#   ('distributions.',
#    <pyspark.resultiterable.ResultIterable at 0x7fe108bd9c10>),
#   ('[Configuration',
#    <pyspark.resultiterable.ResultIterable at 0x7fe1185d6e50>),
#   ('Guide](http://spark.apache.org/docs/latest/configuration.html)',
#    <pyspark.resultiterable.ResultIterable at 0x7fe1185d62e0>),
#   ('online', <pyspark.resultiterable.ResultIterable at 0x7fe1185d6310>),
#   ('overview', <pyspark.resultiterable.ResultIterable at 0x7fe1185d6460>),
#   ('configure', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d62e0>),
#   ('Spark.', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6370>)],
#  [('a', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d63d0>),
#   ('fast', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6430>),
#   ('and', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6490>),
#   ('general', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d64f0>),
#   ('cluster', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6580>),
#   ('computing', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6610>),
#   ('system', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6670>),
#   ('for', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d66d0>),
#   ('Big', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6730>),
#   ('Data.', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6790>),
#   ('Python,', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d67f0>),
#   ('R,', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6880>),
#   ('that', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d68e0>),
#   ('graphs', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6970>),
#   ('data', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d69d0>),
#   ('also', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6a30>),
#   ('rich', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6a90>),
#   ('higher-level', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6af0>),
#   ('including', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6b50>),
#   ('DataFrames,', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6be0>),
#   ('Streaming', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6c40>),
#   ('stream', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6ca0>),
#   ('processing.', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6d00>),
#   ('<http://spark.apache.org/>',
#    <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6d60>),
#   ('##', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6dc0>),
#   ('Online', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6e20>),
#   ('You', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6e80>),
#   ('can', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6ee0>),
#   ('find', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6f40>),
#   ('the', <pyspark.resultiterable.ResultIterable at 0x7fe0f84d6fa0>),
#   ('documentation,',
#    <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc040>),
#   ('on', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc0a0>),
#   ('web', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc100>),
#   ('page](http://spark.apache.org/documentation.html)',
#    <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc160>),
#   ('wiki](https://cwiki.apache.org/confluence/display/SPARK).',
#    <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc1c0>),
#   ('This', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc220>),
#   ('file', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc2b0>),
#   ('contains', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc310>),
#   ('setup', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc370>),
#   ('built', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc3d0>),
#   ('Maven](http://maven.apache.org/).',
#    <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc430>),
#   ('To', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc490>),
#   ('build', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc520>),
#   ('its', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc580>),
#   ('example', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc5e0>),
#   ('programs,', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc670>),
#   ('build/mvn', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc6d0>),
#   ('-DskipTests', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc730>),
#   ('clean', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc790>),
#   ('package', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc7f0>),
#   ('(You', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc850>),
#   ('not', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc8b0>),
#   ('need', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc910>),
#   ('to', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc970>),
#   ('if', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cc9d0>),
#   ('you', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cca30>),
#   ('pre-built', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cca90>),
#   ('package.)', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ccaf0>),
#   ('one', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ccb50>),
#   ('thread', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ccbe0>),
#   ('by', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ccc40>),
#   ('option', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ccca0>),
#   ('with', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ccd00>),
#   ('Maven,', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ccd60>),
#   ('see', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ccdc0>),
#   ('["Parallel', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cce50>),
#   ('builds', <pyspark.resultiterable.ResultIterable at 0x7fe0f84cceb0>),
#   ('More', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ccf10>),
#   ('detailed', <pyspark.resultiterable.ResultIterable at 0x7fe0f84ccf70>),
#   ('available', <pyspark.resultiterable.ResultIterable at 0x7fe0f84db040>),
#   ('from', <pyspark.resultiterable.ResultIterable at 0x7fe0f84db0a0>),
#   ('["Building', <pyspark.resultiterable.ResultIterable at 0x7fe0f84db100>),
#   ('For', <pyspark.resultiterable.ResultIterable at 0x7fe0f84db160>),
#   ('[Eclipse](https://cwiki.apache.org/confluence/display/SPARK/Useful+Developer+Tools#UsefulDeveloperTools-Eclipse)',
#    <pyspark.resultiterable.ResultIterable at 0x7fe0f84db1f0>),
#   ('[IntelliJ](https://cwiki.apache.org/confluence/display/SPARK/Useful+Developer+Tools#UsefulDeveloperTools-IntelliJ).',
#    <pyspark.resultiterable.ResultIterable at 0x7fe0f84db250>),
#   ('Scala', <pyspark.resultiterable.ResultIterable at 0x7fe0f84db2b0>),
#   ('easiest', <pyspark.resultiterable.ResultIterable at 0x7fe0f84db340>),
#   ('through', <pyspark.resultiterable.ResultIterable at 0x7fe0f84db3a0>),
#   ('shell:', <pyspark.resultiterable.ResultIterable at 0x7fe0f84db400>),
#   ('./bin/spark-shell',
#    <pyspark.resultiterable.ResultIterable at 0x7fe0f84db490>),
#   ('command,', <pyspark.resultiterable.ResultIterable at 0x7fe0f84db4f0>),
#   ('which', <pyspark.resultiterable.ResultIterable at 0x7fe0f84db580>),
#   ('should', <pyspark.resultiterable.ResultIterable at 0x7fe0f84db610>),
#   ('return', <pyspark.resultiterable.ResultIterable at 0x7fe0f84db6a0>),
#   ('sc.parallelize(1',
#    <pyspark.resultiterable.ResultIterable at 0x7fe0f84db730>),
#   ('prefer', <pyspark.resultiterable.ResultIterable at 0x7fe0f84db790>),
#   ('./bin/pyspark', <pyspark.resultiterable.ResultIterable at 0x7fe0f84db7f0>),
#   ('>>>', <pyspark.resultiterable.ResultIterable at 0x7fe0f84db850>),
#   ('sc.parallelize(range(1000)).count()',
#    <pyspark.resultiterable.ResultIterable at 0x7fe0f84db8b0>),
#   ('Programs', <pyspark.resultiterable.ResultIterable at 0x7fe0f84db910>),
#   ('comes', <pyspark.resultiterable.ResultIterable at 0x7fe0f84db970>),
#   ('sample', <pyspark.resultiterable.ResultIterable at 0x7fe0f84db9d0>),
#   ('`examples`', <pyspark.resultiterable.ResultIterable at 0x7fe0f84dba30>),
#   ('directory.', <pyspark.resultiterable.ResultIterable at 0x7fe0f84dbac0>),
#   ('<class>', <pyspark.resultiterable.ResultIterable at 0x7fe0f84dbb20>),
#   ('will', <pyspark.resultiterable.ResultIterable at 0x7fe0f84dbb80>),
#   ('Pi', <pyspark.resultiterable.ResultIterable at 0x7fe0f84dbbe0>),
#   ('locally.', <pyspark.resultiterable.ResultIterable at 0x7fe0f84dbc40>),
#   ('MASTER', <pyspark.resultiterable.ResultIterable at 0x7fe0f84dbca0>),
#   ('environment', <pyspark.resultiterable.ResultIterable at 0x7fe0f84dbd00>),
#   ('running', <pyspark.resultiterable.ResultIterable at 0x7fe0f84dbd60>),
#   ('submit', <pyspark.resultiterable.ResultIterable at 0x7fe0f84dbdc0>),
#   ('cluster.', <pyspark.resultiterable.ResultIterable at 0x7fe0f84dbe20>),
#   ('be', <pyspark.resultiterable.ResultIterable at 0x7fe0f84dbe80>),
#   ('mesos://', <pyspark.resultiterable.ResultIterable at 0x7fe0f84dbf10>),
#   ('or', <pyspark.resultiterable.ResultIterable at 0x7fe0f84dbf70>),
#   ('"yarn"', <pyspark.resultiterable.ResultIterable at 0x7fe0f84de040>),
#   ('thread,', <pyspark.resultiterable.ResultIterable at 0x7fe0f84de0a0>),
#   ('"local[N]"', <pyspark.resultiterable.ResultIterable at 0x7fe0f84de100>),
#   ('threads.', <pyspark.resultiterable.ResultIterable at 0x7fe0f84de160>),
#   ('MASTER=spark://host:7077',
#    <pyspark.resultiterable.ResultIterable at 0x7fe0f84de1c0>),
#   ('Many', <pyspark.resultiterable.ResultIterable at 0x7fe0f84de220>),
#   ('given.', <pyspark.resultiterable.ResultIterable at 0x7fe0f84de280>),
#   ('Running', <pyspark.resultiterable.ResultIterable at 0x7fe0f84de2e0>),
#   ('Tests', <pyspark.resultiterable.ResultIterable at 0x7fe0f84de340>),
#   ('first', <pyspark.resultiterable.ResultIterable at 0x7fe0f84de3a0>),
#   ('requires', <pyspark.resultiterable.ResultIterable at 0x7fe0f84de400>),
#   ('[building', <pyspark.resultiterable.ResultIterable at 0x7fe0f84de460>),
#   ('how', <pyspark.resultiterable.ResultIterable at 0x7fe0f84de4c0>),
#   ('[run', <pyspark.resultiterable.ResultIterable at 0x7fe0f84de550>),
#   ('tests](https://cwiki.apache.org/confluence/display/SPARK/Useful+Developer+Tools).',
#    <pyspark.resultiterable.ResultIterable at 0x7fe0f84de5b0>),
#   ('A', <pyspark.resultiterable.ResultIterable at 0x7fe0f84de610>),
#   ('Hadoop', <pyspark.resultiterable.ResultIterable at 0x7fe0f84de670>),
#   ('Versions', <pyspark.resultiterable.ResultIterable at 0x7fe0f84de700>),
#   ('core', <pyspark.resultiterable.ResultIterable at 0x7fe0f84de760>),
#   ('talk', <pyspark.resultiterable.ResultIterable at 0x7fe0f84de7c0>),
#   ('protocols', <pyspark.resultiterable.ResultIterable at 0x7fe0f84de820>),
#   ('same', <pyspark.resultiterable.ResultIterable at 0x7fe0f84de880>),
#   ('your', <pyspark.resultiterable.ResultIterable at 0x7fe0f84de8e0>),
#   ('runs.', <pyspark.resultiterable.ResultIterable at 0x7fe0f84de940>),
#   ('["Specifying', <pyspark.resultiterable.ResultIterable at 0x7fe0f84de9a0>),
#   ('Version"](http://spark.apache.org/docs/latest/building-spark.html#specifying-the-hadoop-version)',
#    <pyspark.resultiterable.ResultIterable at 0x7fe0f84dea00>),
#   ('building', <pyspark.resultiterable.ResultIterable at 0x7fe0f84dea60>),
#   ('Configuration',
#    <pyspark.resultiterable.ResultIterable at 0x7fe0f84deaf0>)]]

# %%
word_count = grouped_word_rdd.mapValues(lambda x : sum(x))

# %%
word_count.glom().collect()
# Out:
# [[('#', 1),
#   ('Apache', 1),
#   ('Spark', 15),
#   ('', 68),
#   ('is', 6),
#   ('It', 2),
#   ('provides', 1),
#   ('high-level', 1),
#   ('APIs', 1),
#   ('in', 6),
#   ('Scala,', 1),
#   ('Java,', 1),
#   ('an', 4),
#   ('optimized', 1),
#   ('engine', 1),
#   ('supports', 2),
#   ('computation', 1),
#   ('analysis.', 1),
#   ('set', 2),
#   ('of', 5),
#   ('tools', 1),
#   ('SQL', 2),
#   ('MLlib', 1),
#   ('machine', 1),
#   ('learning,', 1),
#   ('GraphX', 1),
#   ('graph', 1),
#   ('processing,', 1),
#   ('Documentation', 1),
#   ('latest', 1),
#   ('programming', 1),
#   ('guide,', 1),
#   ('[project', 2),
#   ('README', 1),
#   ('only', 1),
#   ('basic', 1),
#   ('instructions.', 1),
#   ('Building', 1),
#   ('using', 5),
#   ('[Apache', 1),
#   ('run:', 1),
#   ('do', 2),
#   ('this', 1),
#   ('downloaded', 1),
#   ('more', 1),
#   ('than', 1),
#   ('-T', 1),
#   ('Maven', 1),
#   ('3"](https://cwiki.apache.org/confluence/display/MAVEN/Parallel+builds+in+Maven+3).',
#    1),
#   ('documentation', 3),
#   ('project', 1),
#   ('site,', 1),
#   ('at', 2),
#   ('Spark"](http://spark.apache.org/docs/latest/building-spark.html).', 1),
#   ('developing', 1),
#   ('IDE,', 1),
#   ('Interactive', 2),
#   ('Shell', 2),
#   ('The', 1),
#   ('way', 1),
#   ('start', 1),
#   ('Try', 1),
#   ('following', 2),
#   ('1000:', 2),
#   ('scala>', 1),
#   ('1000).count()', 1),
#   ('Python', 2),
#   ('Alternatively,', 1),
#   ('use', 3),
#   ('And', 1),
#   ('run', 7),
#   ('Example', 1),
#   ('several', 1),
#   ('programs', 2),
#   ('them,', 1),
#   ('`./bin/run-example', 1),
#   ('[params]`.', 1),
#   ('example:', 1),
#   ('./bin/run-example', 2),
#   ('SparkPi', 2),
#   ('variable', 1),
#   ('when', 1),
#   ('examples', 2),
#   ('spark://', 1),
#   ('URL,', 1),
#   ('YARN,', 1),
#   ('"local"', 1),
#   ('locally', 2),
#   ('N', 1),
#   ('abbreviated', 1),
#   ('class', 2),
#   ('name', 1),
#   ('package.', 1),
#   ('instance:', 1),
#   ('print', 1),
#   ('usage', 1),
#   ('help', 1),
#   ('no', 1),
#   ('params', 1),
#   ('are', 1),
#   ('Testing', 1),
#   ('Spark](#building-spark).', 1),
#   ('Once', 1),
#   ('built,', 1),
#   ('tests', 2),
#   ('using:', 1),
#   ('./dev/run-tests', 1),
#   ('Please', 3),
#   ('guidance', 2),
#   ('module,', 1),
#   ('individual', 1),
#   ('Note', 1),
#   ('About', 1),
#   ('uses', 1),
#   ('library', 1),
#   ('HDFS', 1),
#   ('other', 1),
#   ('Hadoop-supported', 1),
#   ('storage', 1),
#   ('systems.', 1),
#   ('Because', 1),
#   ('have', 1),
#   ('changed', 1),
#   ('different', 1),
#   ('versions', 1),
#   ('Hadoop,', 2),
#   ('must', 1),
#   ('against', 1),
#   ('version', 1),
#   ('refer', 2),
#   ('particular', 2),
#   ('distribution', 1),
#   ('Hive', 2),
#   ('Thriftserver', 1),
#   ('distributions.', 1),
#   ('[Configuration', 1),
#   ('Guide](http://spark.apache.org/docs/latest/configuration.html)', 1),
#   ('online', 1),
#   ('overview', 1),
#   ('configure', 1),
#   ('Spark.', 1)],
#  [('a', 8),
#   ('fast', 1),
#   ('and', 11),
#   ('general', 2),
#   ('cluster', 2),
#   ('computing', 1),
#   ('system', 1),
#   ('for', 11),
#   ('Big', 1),
#   ('Data.', 1),
#   ('Python,', 2),
#   ('R,', 1),
#   ('that', 2),
#   ('graphs', 1),
#   ('data', 1),
#   ('also', 4),
#   ('rich', 1),
#   ('higher-level', 1),
#   ('including', 3),
#   ('DataFrames,', 1),
#   ('Streaming', 1),
#   ('stream', 1),
#   ('processing.', 1),
#   ('<http://spark.apache.org/>', 1),
#   ('##', 8),
#   ('Online', 1),
#   ('You', 4),
#   ('can', 7),
#   ('find', 1),
#   ('the', 22),
#   ('documentation,', 1),
#   ('on', 5),
#   ('web', 1),
#   ('page](http://spark.apache.org/documentation.html)', 1),
#   ('wiki](https://cwiki.apache.org/confluence/display/SPARK).', 1),
#   ('This', 2),
#   ('file', 1),
#   ('contains', 1),
#   ('setup', 1),
#   ('built', 1),
#   ('Maven](http://maven.apache.org/).', 1),
#   ('To', 2),
#   ('build', 4),
#   ('its', 1),
#   ('example', 3),
#   ('programs,', 1),
#   ('build/mvn', 1),
#   ('-DskipTests', 1),
#   ('clean', 1),
#   ('package', 1),
#   ('(You', 1),
#   ('not', 1),
#   ('need', 1),
#   ('to', 14),
#   ('if', 4),
#   ('you', 4),
#   ('pre-built', 1),
#   ('package.)', 1),
#   ('one', 3),
#   ('thread', 1),
#   ('by', 1),
#   ('option', 1),
#   ('with', 4),
#   ('Maven,', 1),
#   ('see', 3),
#   ('["Parallel', 1),
#   ('builds', 1),
#   ('More', 1),
#   ('detailed', 2),
#   ('available', 1),
#   ('from', 1),
#   ('["Building', 1),
#   ('For', 3),
#   ('[Eclipse](https://cwiki.apache.org/confluence/display/SPARK/Useful+Developer+Tools#UsefulDeveloperTools-Eclipse)',
#    1),
#   ('[IntelliJ](https://cwiki.apache.org/confluence/display/SPARK/Useful+Developer+Tools#UsefulDeveloperTools-IntelliJ).',
#    1),
#   ('Scala', 2),
#   ('easiest', 1),
#   ('through', 1),
#   ('shell:', 2),
#   ('./bin/spark-shell', 1),
#   ('command,', 2),
#   ('which', 2),
#   ('should', 2),
#   ('return', 2),
#   ('sc.parallelize(1', 1),
#   ('prefer', 1),
#   ('./bin/pyspark', 1),
#   ('>>>', 1),
#   ('sc.parallelize(range(1000)).count()', 1),
#   ('Programs', 1),
#   ('comes', 1),
#   ('sample', 1),
#   ('`examples`', 2),
#   ('directory.', 1),
#   ('<class>', 1),
#   ('will', 1),
#   ('Pi', 1),
#   ('locally.', 1),
#   ('MASTER', 1),
#   ('environment', 1),
#   ('running', 1),
#   ('submit', 1),
#   ('cluster.', 1),
#   ('be', 2),
#   ('mesos://', 1),
#   ('or', 3),
#   ('"yarn"', 1),
#   ('thread,', 1),
#   ('"local[N]"', 1),
#   ('threads.', 1),
#   ('MASTER=spark://host:7077', 1),
#   ('Many', 1),
#   ('given.', 1),
#   ('Running', 1),
#   ('Tests', 1),
#   ('first', 1),
#   ('requires', 1),
#   ('[building', 1),
#   ('how', 2),
#   ('[run', 1),
#   ('tests](https://cwiki.apache.org/confluence/display/SPARK/Useful+Developer+Tools).',
#    1),
#   ('A', 1),
#   ('Hadoop', 3),
#   ('Versions', 1),
#   ('core', 1),
#   ('talk', 1),
#   ('protocols', 1),
#   ('same', 1),
#   ('your', 1),
#   ('runs.', 1),
#   ('["Specifying', 1),
#   ('Version"](http://spark.apache.org/docs/latest/building-spark.html#specifying-the-hadoop-version)',
#    1),
#   ('building', 2),
#   ('Configuration', 1)]]

# %%
sc.stop()
